# %%
import numpy as np
import random
import time
import gym
from collections import defaultdict

def initialize_q_table(states, actions):
    """Initialize the Q-table with small random values."""
    return np.random.uniform(low=-0.01, high=0.01, size=(states, actions))

def choose_action(state, q_table, epsilon):
    """Choose an action using epsilon-greedy strategy."""
    if random.uniform(0, 1) < epsilon:
        return random.randint(0, q_table.shape[1] - 1)
    else:
        return np.argmax(q_table[state])

def choose_action_mc(state, q_table, epsilon, action_space):
    """Choose an action for Monte Carlo using epsilon-greedy strategy."""
    if random.uniform(0, 1) < epsilon:
        return random.randint(0, action_space - 1)
    else:
        return np.argmax(q_table[state])

def update_q_table(q_table, state, action, reward, next_state, next_action, alpha, gamma):
    """Update the Q-value using the SARSA update rule."""
    state, action, next_state, next_action = int(state), int(action), int(next_state), int(next_action)
    td_target = reward + gamma * q_table[next_state, next_action]
    td_error = td_target - q_table[state, action]
    q_table[state, action] += alpha * td_error

def sarsa(env, episodes, alpha, gamma, epsilon, epsilon_decay):
    """SARSA algorithm implementation."""
    q_table = initialize_q_table(env.observation_space.n, env.action_space.n)
    start_time = time.time()

    for episode in range(episodes):
        state = env.reset()
        if isinstance(state, tuple):
            state = state[0]

        action = choose_action(state, q_table, epsilon)
        total_reward = 0

        print(f"Episode {episode + 1}/{episodes} (SARSA)")

        while True:
            result = env.step(action)
            if len(result) == 5:
                next_state, reward, done, truncated, _ = result
            elif len(result) == 4:
                next_state, reward, done, truncated = result
            else:
                raise ValueError("Unexpected return format from env.step()")

            if isinstance(next_state, tuple):
                next_state = next_state[0]

            next_action = choose_action(next_state, q_table, epsilon)
            update_q_table(q_table, state, action, reward, next_state, next_action, alpha, gamma)

            total_reward += reward
            state, action = next_state, next_action

            if done or truncated:
                print(f"Episode finished with total reward: {total_reward}\n")
                break

        epsilon = max(epsilon * epsilon_decay, 0.01)

    elapsed_time = time.time() - start_time
    print(f"Total time for SARSA: {elapsed_time:.2f} seconds")
    return q_table, elapsed_time

def monte_carlo(env, episodes, gamma, epsilon, epsilon_decay):
    """Monte Carlo control with epsilon-greedy policy."""
    q_table = defaultdict(lambda: np.zeros(env.action_space.n))
    returns = defaultdict(list)  # Store returns for state-action pairs
    start_time = time.time()

    for episode in range(episodes):
        state = env.reset()
        if isinstance(state, tuple):
            state = state[0]

        episode_data = []  # To store state, action, reward
        total_reward = 0

        print(f"Episode {episode + 1}/{episodes} (Monte Carlo)")

        while True:
            action = choose_action_mc(state, q_table, epsilon, env.action_space.n)
            result = env.step(action)

            if len(result) == 5:
                next_state, reward, done, truncated, _ = result
            elif len(result) == 4:
                next_state, reward, done, truncated = result
            else:
                raise ValueError("Unexpected return format from env.step()")

            if isinstance(next_state, tuple):
                next_state = next_state[0]

            episode_data.append((state, action, reward))
            total_reward += reward
            state = next_state

            if done or truncated:
                print(f"Episode finished with total reward: {total_reward}\n")
                break

        # Calculate returns and update Q-values
        G = 0  # Initialize return
        visited = set()

        for state, action, reward in reversed(episode_data):
            G = reward + gamma * G
            if (state, action) not in visited:
                visited.add((state, action))
                returns[(state, action)].append(G)
                q_table[state][action] = np.mean(returns[(state, action)])

        epsilon = max(epsilon * epsilon_decay, 0.01)

    elapsed_time = time.time() - start_time
    print(f"Total time for Monte Carlo: {elapsed_time:.2f} seconds")
    return q_table, elapsed_time

if __name__ == "__main__":
    env = gym.make("FrozenLake-v1", is_slippery=False, render_mode="rgb_array")

    # Hyperparameters
    episodes = 500
    alpha = 0.3  # Learning rate (SARSA only)
    gamma = 0.99  # Discount factor
    epsilon = 1.0  # Exploration rate
    epsilon_decay = 0.995

    # Run SARSA
    sarsa_q_table, sarsa_time = sarsa(env, episodes, alpha, gamma, epsilon, epsilon_decay)

    # Run Monte Carlo
    mc_q_table, mc_time = monte_carlo(env, episodes, gamma, epsilon, epsilon_decay)

    # Display Comparison Table
    print("\nComparison Table:")
    print("Algorithm    | Time (seconds)")
    print("------------------------------")
    print(f"SARSA        | {sarsa_time:.2f}")
    print(f"Monte Carlo  | {mc_time:.2f}")

    print("\nTrained Q-Table (SARSA):")
    print(sarsa_q_table)

    print("\nTrained Q-Table (Monte Carlo):")
    for state, actions in mc_q_table.items():
        print(f"State {state}: {actions}")
# Out:
# Episode 1/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 2/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 3/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 4/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 5/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 6/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 7/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 8/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 9/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 10/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 11/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 12/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 13/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 14/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 15/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 16/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 17/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 18/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 19/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 20/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 21/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 22/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 23/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 24/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 25/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 26/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 27/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 28/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 29/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 30/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 31/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 32/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 33/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 34/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 35/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 36/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 37/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 38/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 39/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 40/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 41/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 42/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 43/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 44/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 45/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 46/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 47/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 48/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 49/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 50/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 51/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 52/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 53/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 54/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 55/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 56/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 57/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 58/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 59/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 60/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 61/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 62/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 63/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 64/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 65/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 66/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 67/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 68/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 69/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 70/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 71/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 72/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 73/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 74/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 75/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 76/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 77/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 78/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 79/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 80/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 81/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 82/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 83/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 84/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 85/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 86/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 87/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 88/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 89/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 90/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 91/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 92/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 93/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 94/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 95/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 96/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 97/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 98/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 99/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 100/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 101/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 102/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 103/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 104/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 105/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 106/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 107/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 108/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 109/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 110/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 111/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 112/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 113/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 114/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 115/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 116/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 117/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 118/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 119/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 120/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 121/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 122/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 123/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 124/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 125/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 126/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 127/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 128/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 129/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 130/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 131/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 132/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 133/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 134/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 135/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 136/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 137/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 138/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 139/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 140/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 141/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 142/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 143/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 144/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 145/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 146/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 147/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 148/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 149/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 150/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 151/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 152/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 153/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 154/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 155/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 156/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 157/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 158/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 159/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 160/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 161/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 162/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 163/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 164/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 165/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 166/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 167/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 168/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 169/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 170/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 171/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 172/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 173/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 174/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 175/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 176/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 177/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 178/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 179/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 180/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 181/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 182/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode 183/500 (SARSA)
# Episode finished with total reward: 0.0
#
# Episode 184/500 (SARSA)
# Episode finished with total reward: 1.0
#
# Episode
500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 441/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 442/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 443/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 444/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 445/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 446/500 (Monte Carlo)
# C:\Users\Trushar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode finished with total reward: 0.0
#
# Episode 447/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 448/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 449/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 450/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 451/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 452/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 453/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 454/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 455/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 456/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 457/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 458/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 459/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 460/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 461/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 462/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 463/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 464/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 465/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 466/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 467/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 468/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 469/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 470/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 471/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 472/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 473/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 474/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 475/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 476/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 477/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 478/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 479/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 480/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 481/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 482/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 483/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 484/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 485/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 486/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 487/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 488/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 489/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 490/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 491/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 492/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 493/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 494/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 495/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 496/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 497/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 498/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 499/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Episode 500/500 (Monte Carlo)
# Episode finished with total reward: 0.0
#
# Total time for Monte Carlo: 0.22 seconds
#
# Comparison Table:
# Algorithm    | Time (seconds)
# ------------------------------
# SARSA        | 0.05
# Monte Carlo  | 0.22
#
# Trained Q-Table (SARSA):
# [[ 6.95036225e-01  5.17590037e-01  8.54280672e-01  6.48784018e-01]
#  [ 6.00777116e-01  5.97729605e-03  9.03202025e-01  6.28303164e-01]
#  [ 5.20610169e-01  9.66853436e-01  5.35855263e-01  5.84003213e-01]
#  [ 7.14908497e-01  5.81607247e-03  3.68657754e-01  2.74469483e-01]
#  [ 2.56150542e-01  1.19671141e-02  6.64828127e-03  7.09201160e-01]
#  [ 4.17830830e-03 -5.23418602e-03 -8.31603849e-03  6.82615556e-03]
#  [ 5.41729615e-03  9.82925172e-01  5.96349167e-03  4.04052370e-01]
#  [-9.31885737e-03  8.03894367e-03  3.13492672e-03 -9.37261560e-04]
#  [ 3.93897683e-02  2.78365719e-04  1.66105142e-01 -1.01635601e-03]
#  [ 3.80065759e-02  2.81088703e-01  9.55146611e-01  2.76008508e-03]
#  [ 8.35512278e-01  9.94738036e-01  6.83118106e-03  7.67785559e-01]
#  [ 1.50359087e-03  9.56624066e-03 -6.29039891e-03 -2.54608516e-03]
#  [ 2.64703300e-03 -1.23831295e-03 -3.37256534e-03  3.28920378e-03]
#  [ 1.60119816e-03  4.89106293e-01  9.77628689e-01  4.58977885e-03]
#  [ 8.21892851e-01  9.39920735e-01  1.00484292e+00  8.67570588e-01]
#  [-1.92893271e-03 -2.29389927e-03 -1.16073020e-03  4.90048468e-03]]
#
# Trained Q-Table (Monte Carlo):
# State 1: [0. 0. 0. 0.]
# State 0: [0. 0. 0. 0.]
# State 4: [0. 0. 0. 0.]
# State 9: [0. 0. 0. 0.]
# State 8: [0. 0. 0. 0.]
# State 3: [0. 0. 0. 0.]
# State 2: [0. 0. 0. 0.]
# State 6: [0. 0. 0. 0.]
# State 10: [0. 0. 0. 0.]
# State 13: [0. 0. 0. 0.]
# State 14: [0. 0. 0. 0.]

# %%
# For visualizing frozen lake but not able to visualize
import os
os.environ["XDG_RUNTIME_DIR"] = "/tmp/runtime-$(id -u)"

# i also tried with this one but didn't work
env = gym.make("FrozenLake-v1", is_slippery=False, render_mode="human")
