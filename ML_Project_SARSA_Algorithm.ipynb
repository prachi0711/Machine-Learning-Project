# %%
import numpy as np
import random
import time
import gym

def initialize_q_table(states, actions):
    """Initialize the Q-table with small random values."""
    return np.random.uniform(low=-0.01, high=0.01, size=(states, actions))

def choose_action(state, q_table, epsilon):
    """Choose an action using epsilon-greedy strategy."""
    if random.uniform(0, 1) < epsilon:
        return random.randint(0, q_table.shape[1] - 1) 
    else:
        return np.argmax(q_table[state]) 

def update_q_table(q_table, state, action, reward, next_state, next_action, alpha, gamma):
    """Update the Q-value using the SARSA update rule."""
    state = int(state)
    action = int(action)
    next_state = int(next_state)
    next_action = int(next_action)
    
    td_target = reward + gamma * q_table[next_state, next_action]
    td_error = td_target - q_table[state, action]
    q_table[state, action] += alpha * td_error

def sarsa(env, episodes, alpha, gamma, epsilon, epsilon_decay):
    """SARSA algorithm implementation."""
    q_table = initialize_q_table(env.observation_space.n, env.action_space.n)

    start_time = time.time()

    for episode in range(episodes):
        state = env.reset()
        if isinstance(state, tuple): 
            state = state[0]

        action = choose_action(state, q_table, epsilon)
        total_reward = 0 
        
        print(f"Episode {episode + 1}/{episodes}")

        while True:
            result = env.step(action)
            if len(result) == 5: 
                next_state, reward, done, truncated, _ = result
            elif len(result) == 4: 
                next_state, reward, done, truncated = result
            else:
                raise ValueError("Unexpected return format from env.step()")

            if isinstance(next_state, tuple):
                next_state = next_state[0]

            next_action = choose_action(next_state, q_table, epsilon)
            update_q_table(q_table, state, action, reward, next_state, next_action, alpha, gamma)

            total_reward += reward 
            state, action = next_state, next_action

            # Render the environment few times
            if episode % 10 == 0:
                env.render()

            if done or truncated:
                print(f"Episode finished with total reward: {total_reward}\n")
                break

        epsilon = max(epsilon * epsilon_decay, 0.01) 

    elapsed_time = time.time() - start_time
    print(f"Total time for SARSA: {elapsed_time:.2f} seconds")
    return q_table, elapsed_time

if __name__ == "__main__":
    env = gym.make("FrozenLake-v1", is_slippery=False, render_mode="rgb_array")

    # Hyperparameters
    episodes = 500
    alpha = 0.3  # Learning rate
    gamma = 0.99  # Discount factor
    epsilon = 1.0  # Exploration rate
    epsilon_decay = 0.995

    q_table, sarsa_time = sarsa(env, episodes, alpha, gamma, epsilon, epsilon_decay)

    print("Trained Q-Table:")
    print(q_table)

    # table for algorithms to compare
    print("\nComparison Table:")
    print("Algorithm    | Time (seconds)")
    print("------------------------------")
    print(f"SARSA        | {sarsa_time:.2f}")
# Out:
# Episode 1/500
# Episode finished with total reward: 0.0
#
# Episode 2/500
# Episode finished with total reward: 0.0
#
# Episode 3/500
# Episode finished with total reward: 0.0
#
# Episode 4/500
# Episode finished with total reward: 0.0
#
# Episode 5/500
# Episode finished with total reward: 0.0
#
# Episode 6/500
# Episode finished with total reward: 0.0
#
# Episode 7/500
# Episode finished with total reward: 0.0
#
# Episode 8/500
# Episode finished with total reward: 0.0
#
# Episode 9/500
# Episode finished with total reward: 0.0
#
# Episode 10/500
# Episode finished with total reward: 0.0
#
# Episode 11/500
# Episode finished with total reward: 0.0
#
# Episode 12/500
# Episode finished with total reward: 0.0
#
# Episode 13/500
# Episode finished with total reward: 0.0
#
# Episode 14/500
# Episode finished with total reward: 0.0
#
# Episode 15/500
# Episode finished with total reward: 0.0
#
# Episode 16/500
# Episode finished with total reward: 0.0
#
# Episode 17/500
# Episode finished with total reward: 0.0
#
# Episode 18/500
# Episode finished with total reward: 0.0
#
# Episode 19/500
# Episode finished with total reward: 0.0
#
# Episode 20/500
# Episode finished with total reward: 0.0
#
# Episode 21/500
# Episode finished with total reward: 0.0
#
# Episode 22/500
# Episode finished with total reward: 0.0
#
# Episode 23/500
# Episode finished with total reward: 0.0
#
# Episode 24/500
# Episode finished with total reward: 0.0
#
# Episode 25/500
# Episode finished with total reward: 0.0
#
# Episode 26/500
# Episode finished with total reward: 0.0
#
# Episode 27/500
# Episode finished with total reward: 0.0
#
# Episode 28/500
# Episode finished with total reward: 0.0
#
# Episode 29/500
# Episode finished with total reward: 0.0
#
# Episode 30/500
# Episode finished with total reward: 0.0
#
# Episode 31/500
# Episode finished with total reward: 0.0
#
# Episode 32/500
# Episode finished with total reward: 1.0
#
# Episode 33/500
# Episode finished with total reward: 0.0
#
# Episode 34/500
# Episode finished with total reward: 0.0
#
# Episode 35/500
# Episode finished with total reward: 0.0
#
# Episode 36/500
# Episode finished with total reward: 0.0
#
# Episode 37/500
# Episode finished with total reward: 0.0
#
# Episode 38/500
# Episode finished with total reward: 0.0
#
# Episode 39/500
# Episode finished with total reward: 0.0
#
# Episode 40/500
# Episode finished with total reward: 0.0
#
# Episode 41/500
# Episode finished with total reward: 0.0
#
# Episode 42/500
# Episode finished with total reward: 0.0
#
# Episode 43/500
# Episode finished with total reward: 0.0
#
# Episode 44/500
# Episode finished with total reward: 0.0
#
# Episode 45/500
# Episode finished with total reward: 0.0
#
# Episode 46/500
# Episode finished with total reward: 0.0
#
# Episode 47/500
# Episode finished with total reward: 0.0
#
# Episode 48/500
# Episode finished with total reward: 0.0
#
# Episode 49/500
# Episode finished with total reward: 0.0
#
# Episode 50/500
# Episode finished with total reward: 0.0
#
# Episode 51/500
# Episode finished with total reward: 0.0
#
# Episode 52/500
# Episode finished with total reward: 0.0
#
# Episode 53/500
# Episode finished with total reward: 0.0
#
# Episode 54/500
# Episode finished with total reward: 0.0
#
# Episode 55/500
# Episode finished with total reward: 0.0
#
# Episode 56/500
# Episode finished with total reward: 0.0
#
# Episode 57/500
# Episode finished with total reward: 0.0
#
# Episode 58/500
# Episode finished with total reward: 0.0
#
# Episode 59/500
# Episode finished with total reward: 0.0
#
# Episode 60/500
# Episode finished with total reward: 0.0
#
# Episode 61/500
# Episode finished with total reward: 0.0
#
# Episode 62/500
# Episode finished with total reward: 0.0
#
# Episode 63/500
# Episode finished with total reward: 0.0
#
# Episode 64/500
# Episode finished with total reward: 0.0
#
# Episode 65/500
# Episode finished with total reward: 0.0
#
# Episode 66/500
# Episode finished with total reward: 0.0
#
# Episode 67/500
# Episode finished with total reward: 0.0
#
# Episode 68/500
# Episode finished with total reward: 0.0
#
# Episode 69/500
# Episode finished with total reward: 0.0
#
# Episode 70/500
# Episode finished with total reward: 0.0
#
# Episode 71/500
# Episode finished with total reward: 0.0
#
# Episode 72/500
# Episode finished with total reward: 0.0
#
# Episode 73/500
# Episode finished with total reward: 0.0
#
# Episode 74/500
# Episode finished with total reward: 0.0
#
# Episode 75/500
# Episode finished with total reward: 0.0
#
# Episode 76/500
# Episode finished with total reward: 0.0
#
# Episode 77/500
# Episode finished with total reward: 0.0
#
# Episode 78/500
# Episode finished with total reward: 0.0
#
# Episode 79/500
# Episode finished with total reward: 0.0
#
# Episode 80/500
# Episode finished with total reward: 0.0
#
# Episode 81/500
# Episode finished with total reward: 0.0
#
# Episode 82/500
# Episode finished with total reward: 0.0
#
# Episode 83/500
# Episode finished with total reward: 0.0
#
# Episode 84/500
# Episode finished with total reward: 0.0
#
# Episode 85/500
# Episode finished with total reward: 1.0
#
# Episode 86/500
# Episode finished with total reward: 0.0
#
# Episode 87/500
# Episode finished with total reward: 0.0
#
# Episode 88/500
# Episode finished with total reward: 0.0
#
# Episode 89/500
# Episode finished with total reward: 0.0
#
# Episode 90/500
# Episode finished with total reward: 0.0
#
# Episode 91/500
# Episode finished with total reward: 0.0
#
# Episode 92/500
# Episode finished with total reward: 0.0
#
# Episode 93/500
# Episode finished with total reward: 0.0
#
# Episode 94/500
# Episode finished with total reward: 0.0
#
# Episode 95/500
# Episode finished with total reward: 0.0
#
# Episode 96/500
# Episode finished with total reward: 0.0
#
# Episode 97/500
# Episode finished with total reward: 0.0
#
# Episode 98/500
# Episode finished with total reward: 0.0
#
# Episode 99/500
# Episode finished with total reward: 0.0
#
# Episode 100/500
# Episode finished with total reward: 0.0
#
# Episode 101/500
# Episode finished with total reward: 0.0
#
# Episode 102/500
# Episode finished with total reward: 0.0
#
# Episode 103/500
# Episode finished with total reward: 0.0
#
# Episode 104/500
# Episode finished with total reward: 0.0
#
# Episode 105/500
# Episode finished with total reward: 1.0
#
# Episode 106/500
# Episode finished with total reward: 0.0
#
# Episode 107/500
# Episode finished with total reward: 0.0
#
# Episode 108/500
# Episode finished with total reward: 0.0
#
# Episode 109/500
# Episode finished with total reward: 1.0
#
# Episode 110/500
# Episode finished with total reward: 0.0
#
# Episode 111/500
# Episode finished with total reward: 1.0
#
# Episode 112/500
# Episode finished with total reward: 0.0
#
# Episode 113/500
# Episode finished with total reward: 0.0
#
# Episode 114/500
# Episode finished with total reward: 0.0
#
# Episode 115/500
# Episode finished with total reward: 0.0
#
# Episode 116/500
# Episode finished with total reward: 0.0
#
# Episode 117/500
# Episode finished with total reward: 0.0
#
# Episode 118/500
# Episode finished with total reward: 0.0
#
# Episode 119/500
# Episode finished with total reward: 0.0
#
# Episode 120/500
# Episode finished with total reward: 1.0
#
# Episode 121/500
# Episode finished with total reward: 1.0
#
# Episode 122/500
# Episode finished with total reward: 1.0
#
# Episode 123/500
# Episode finished with total reward: 1.0
#
# Episode 124/500
# Episode finished with total reward: 0.0
#
# Episode 125/500
# Episode finished with total reward: 1.0
#
# Episode 126/500
# Episode finished with total reward: 1.0
#
# Episode 127/500
# Episode finished with total reward: 0.0
#
# Episode 128/500
# Episode finished with total reward: 0.0
#
# Episode 129/500
# Episode finished with total reward: 0.0
#
# Episode 130/500
# Episode finished with total reward: 0.0
#
# Episode 131/500
# Episode finished with total reward: 0.0
#
# Episode 132/500
# Episode finished with total reward: 1.0
#
# Episode 133/500
# Episode finished with total reward: 0.0
#
# Episode 134/500
# Episode finished with total reward: 0.0
#
# Episode 135/500
# Episode finished with total reward: 0.0
#
# Episode 136/500
# Episode finished with total reward: 1.0
#
# Episode 137/500
# Episode finished with total reward: 0.0
#
# Episode 138/500
# Episode finished with total reward: 1.0
#
# Episode 139/500
# Episode finished with total reward: 1.0
#
# Episode 140/500
# Episode finished with total reward: 0.0
#
# Episode 141/500
# Episode finished with total reward: 0.0
#
# Episode 142/500
# Episode finished with total reward: 0.0
#
# Episode 143/500
# Episode finished with total reward: 0.0
#
# Episode 144/500
# Episode finished with total reward: 0.0
#
# Episode 145/500
# Episode finished with total reward: 1.0
#
# Episode 146/500
# Episode finished with total reward: 0.0
#
# Episode 147/500
# Episode finished with total reward: 1.0
#
# Episode 148/500
# Episode finished with total reward: 1.0
#
# Episode 149/500
# Episode finished with total reward: 1.0
#
# Episode 150/500
# Episode finished with total reward: 1.0
#
# Episode 151/500
# Episode finished with total reward: 0.0
#
# Episode 152/500
# Episode finished with total reward: 0.0
#
# Episode 153/500
# Episode finished with total reward: 0.0
#
# Episode 154/500
# Episode finished with total reward: 0.0
#
# Episode 155/500
# Episode finished with total reward: 0.0
#
# Episode 156/500
# Episode finished with total reward: 0.0
#
# Episode 157/500
# Episode finished with total reward: 1.0
#
# Episode 158/500
# Episode finished with total reward: 1.0
#
# Episode 159/500
# Episode finished with total reward: 1.0
#
# Episode 160/500
# Episode finished with total reward: 1.0
#
# Episode 161/500
# Episode finished with total reward: 1.0
#
# Episode 162/500
# Episode finished with total reward: 1.0
#
# Episode 163/500
# Episode finished with total reward: 0.0
#
# Episode 164/500
# Episode finished with total reward: 0.0
#
# Episode 165/500
# Episode finished with total reward: 0.0
#
# Episode 166/500
# Episode finished with total reward: 0.0
#
# Episode 167/500
# Episode finished with total reward: 0.0
#
# Episode 168/500
# Episode finished with total reward: 0.0
#
# Episode 169/500
# Episode finished with total reward: 0.0
#
# Episode 170/500
# Episode finished with total reward: 0.0
#
# Episode 171/500
# Episode finished with total reward: 0.0
#
# Episode 172/500
# Episode finished with total reward: 1.0
#
# Episode 173/500
# Episode finished with total reward: 0.0
#
# Episode 174/500
# Episode finished with total reward: 0.0
#
# Episode 175/500
# Episode finished with total reward: 0.0
#
# Episode 176/500
# Episode finished with total reward: 0.0
#
# Episode 177/500
# Episode finished with total reward: 0.0
#
# Episode 178/500
# Episode finished with total reward: 0.0
#
# Episode 179/500
# Episode finished with total reward: 0.0
#
# Episode 180/500
# Episode finished with total reward: 0.0
#
# Episode 181/500
# Episode finished with total reward: 0.0
#
# Episode 182/500
# Episode finished with total reward: 0.0
#
# Episode 183/500
# Episode finished with total reward: 0.0
#
# Episode 184/500
# Episode finished with total reward: 1.0
#
# Episode 185/500
# Episode finished with total reward: 1.0
#
# Episode 186/500
# Episode finished with total reward: 1.0
#
# Episode 187/500
# Episode finished with total reward: 0.0
#
# Episode 188/500
# Episode finished with total reward: 0.0
#
# Episode 189/500
# Episode finished with total reward: 1.0
#
# Episode 190/500
# Episode finished with total reward: 1.0
#
# Episode 191/500
# Episode finished with total reward: 1.0
#
# Episode 192/500
# Episode finished with total reward: 1.0
#
# Episode 193/500
# Episode finished with total reward: 1.0
#
# Episode 194/500
# Episode finished with total reward: 1.0
#
# Episode 195/500
# Episode finished with total reward: 1.0
#
# Episode 196/500
# Episode finished with total reward: 1.0
#
# Episode 197/500
# Episode finished with total reward: 1.0
#
# Episode 198/500
# Episode finished with total reward: 0.0
#
# Episode 199/500
# Episode finished with total reward: 1.0
#
# Episode 200/500
# Episode finished with total reward: 1.0
#
# Episode 201/500
# Episode finished with total reward: 0.0
#
# Episode 202/500
# Episode finished with total reward: 0.0
#
# Episode 203/500
# Episode finished with total reward: 0.0
#
# Episode 204/500
# Episode finished with total reward: 0.0
#
# Episode 205/500
# Episode finished with total reward: 0.0
#
# Episode 206/500
# Episode finished with total reward: 1.0
#
# Episode 207/500
# Episode finished with total reward: 0.0
#
# Episode 208/500
# Episode finished with total reward: 1.0
#
# Episode 209/500
# Episode finished with total reward: 1.0
#
# Episode 210/500
# Episode finished with total reward: 1.0
#
# Episode 211/500
# Episode finished with total reward: 1.0
#
# Episode 212/500
# Episode finished with total reward: 1.0
#
# Episode 213/500
# Episode finished with total reward: 1.0
#
# Episode 214/500
# Episode finished with total reward: 1.0
#
# Episode 215/500
# Episode finished with total reward: 1.0
#
# Episode 216/500
# Episode finished with total reward: 0.0
#
# Episode 217/500
# Episode finished with total reward: 1.0
#
# Episode 218/500
# Episode finished with total reward: 1.0
#
# Episode 219/500
# Episode finished with total reward: 0.0
#
# Episode 220/500
# Episode finished with total reward: 1.0
#
# Episode 221/500
# Episode finished with total reward: 0.0
#
# Episode 222/500
# Episode finished with total reward: 1.0
#
# Episode 223/500
# Episode finished with total reward: 1.0
#
# Episode 224/500
# Episode finished with total reward: 1.0
#
# Episode 225/500
# Episode finished with total reward: 1.0
#
# Episode 226/500
# Episode finished with total reward: 0.0
#
# Episode 227/500
# Episode finished with total reward: 1.0
#
# Episode 228/500
# Episode finished with total reward: 0.0
#
# Episode 229/500
# Episode finished with total reward: 0.0
#
# Episode 230/500
# Episode finished with total reward: 0.0
#
# Episode 231/500
# Episode finished with total reward: 1.0
#
# Episode 232/500
# Episode finished with total reward: 1.0
#
# Episode 233/500
# Episode finished with total reward: 1.0
#
# Episode 234/500
# Episode finished with total reward: 0.0
#
# Episode 235/500
# Episode finished with total reward: 1.0
#
# Episode 236/500
# Episode finished with total reward: 1.0
#
# Episode 237/500
# Episode finished with total reward: 1.0
#
# Episode 238/500
# Episode finished with total reward: 1.0
#
# Episode 239/500
# Episode finished with total reward: 1.0
#
# Episode 240/500
# Episode finished with total reward: 1.0
#
# Episode 241/500
# Episode finished with total reward: 0.0
#
# Episode 242/500
# Episode finished with total reward: 1.0
#
# Episode 243/500
# Episode finished with total reward: 1.0
#
# Episode 244/500
# Episode finished with total reward: 1.0
#
# Episode 245/500
# Episode finished with total reward: 1.0
#
# Episode 246/500
# Episode finished with total reward: 1.0
#
# Episode 247/500
# Episode finished with total reward: 1.0
#
# Episode 248/500
# Episode finished with total reward: 1.0
#
# Episode 249/500
# Episode finished with total reward: 1.0
#
# Episode 250/500
# Episode finished with total reward: 0.0
#
# Episode 251/500
# Episode finished with total reward: 0.0
#
# Episode 252/500
# Episode finished with total reward: 0.0
#
# Episode 253/500
# Episode finished with total reward: 1.0
#
# Episode 254/500
# Episode finished with total reward: 1.0
#
# Episode 255/500
# Episode finished with total reward: 0.0
#
# Episode 256/500
# Episode finished with total reward: 1.0
#
# Episode 257/500
# Episode finished with total reward: 1.0
#
# Episode 258/500
# Episode finished with total reward: 1.0
#
# Episode 259/500
# Episode finished with total reward: 0.0
#
# Episode 260/500
# Episode finished with total reward: 1.0
#
# Episode 261/500
# Episode finished with total reward: 0.0
#
# Episode 262/500
# Episode finished with total reward: 1.0
#
# Episode 263/500
# Episode finished with total reward: 0.0
#
# Episode 264/500
# Episode finished with total reward: 1.0
#
# Episode 265/500
# Episode finished with total reward: 0.0
#
# Episode 266/500
# Episode finished with total reward: 0.0
#
# Episode 267/500
# Episode finished with total reward: 1.0
#
# Episode 268/500
# Episode finished with total reward: 1.0
#
# Episode 269/500
# Episode finished with total reward: 1.0
#
# Episode 270/500
# Episode finished with total reward: 1.0
#
# Episode 271/500
# Episode finished with total reward: 1.0
#
# Episode 272/500
# Episode finished with total reward: 1.0
#
# Episode 273/500
# Episode finished with total reward: 0.0
#
# Episode 274/500
# Episode finished with total reward: 1.0
#
# Episode 275/500
# Episode finished with total reward: 1.0
#
# Episode 276/500
# Episode finished with total reward: 1.0
#
# Episode 277/500
# Episode finished with total reward: 1.0
#
# Episode 278/500
# Episode finished with total reward: 1.0
#
# Episode 279/500
# Episode finished with total reward: 0.0
#
# Episode 280/500
# Episode finished with total reward: 1.0
#
# Episode 281/500
# Episode finished with total reward: 0.0
#
# Episode 282/500
# Episode finished with total reward: 1.0
#
# Episode 283/500
# Episode finished with total reward: 1.0
#
# Episode 284/500
# Episode finished with total reward: 1.0
#
# Episode 285/500
# Episode finished with total reward: 1.0
#
# Episode 286/500
# Episode finished with total reward: 1.0
#
# Episode 287/500
# Episode finished with total reward: 1.0
#
# Episode 288/500
# Episode finished with total reward: 1.0
#
# Episode 289/500
# Episode finished with total reward: 1.0
#
# Episode 290/500
# Episode finished with total reward: 1.0
#
# Episode 291/500
# Episode finished with total reward: 1.0
#
# Episode 292/500
# Episode finished with total reward: 1.0
#
# Episode 293/500
# Episode finished with total reward: 0.0
#
# Episode 294/500
# Episode finished with total reward: 1.0
#
# Episode 295/500
# Episode finished with total reward: 1.0
#
# Episode 296/500
# Episode finished with total reward: 0.0
#
# Episode 297/500
# Episode finished with total reward: 1.0
#
# Episode 298/500
# Episode finished with total reward: 1.0
#
# Episode 299/500
# Episode finished with total reward: 0.0
#
# Episode 300/500
# Episode finished with total reward: 1.0
#
# Episode 301/500
# Episode finished with total reward: 1.0
#
# Episode 302/500
# Episode finished with total reward: 1.0
#
# Episode 303/500
# Episode finished with total reward: 0.0
#
# Episode 304/500
# Episode finished with total reward: 1.0
#
# Episode 305/500
# Episode finished with total reward: 1.0
#
# Episode 306/500
# Episode finished with total reward: 1.0
#
# Episode 307/500
# Episode finished with total reward: 1.0
#
# Episode 308/500
# Episode finished with total reward: 1.0
#
# Episode 309/500
# Episode finished with total reward: 0.0
#
# Episode 310/500
# Episode finished with total reward: 1.0
#
# Episode 311/500
# Episode finished with total reward: 1.0
#
# Episode 312/500
# Episode finished with total reward: 0.0
#
# Episode 313/500
# Episode finished with total reward: 1.0
#
# Episode 314/500
# Episode finished with total reward: 1.0
#
# Episode 315/500
# Episode finished with total reward: 1.0
#
# Episode 316/500
# Episode finished with total reward: 1.0
#
# Episode 317/500
# Episode finished with total reward: 0.0
#
# Episode 318/500
# Episode finished with total reward: 1.0
#
# Episode 319/500
# Episode finished with total reward: 1.0
#
# Episode 320/500
# Episode finished with total reward: 1.0
#
# Episode 321/500
# Episode finished with total reward: 0.0
#
# Episode 322/500
# Episode finished with total reward: 1.0
#
# Episode 323/500
# Episode finished with total reward: 1.0
#
# Episode 324/500
# Episode finished with total reward: 1.0
#
# Episode 325/500
# Episode finished with total reward: 1.0
#
# Episode 326/500
# Episode finished with total reward: 1.0
#
# Episode 327/500
# Episode finished with total reward: 0.0
#
# Episode 328/500
# Episode finished with total reward: 0.0
#
# Episode 329/500
# Episode finished with total reward: 0.0
#
# Episode 330/500
# Episode finished with total reward: 0.0
#
# Episode 331/500
# Episode finished with total reward: 0.0
#
# Episode 332/500
# Episode finished with total reward: 0.0
#
# Episode 333/500
# Episode finished with total reward: 1.0
#
# Episode 334/500
# Episode finished with total reward: 1.0
#
# Episode 335/500
# Episode finished with total reward: 1.0
#
# Episode 336/500
# Episode finished with total reward: 1.0
#
# Episode 337/500
# Episode finished with total reward: 0.0
#
# Episode 338/500
# Episode finished with total reward: 0.0
#
# Episode 339/500
# Episode finished with total reward: 1.0
#
# Episode 340/500
# Episode finished with total reward: 0.0
#
# Episode 341/500
# Episode finished with total reward: 1.0
#
# Episode 342/500
# Episode finished with total reward: 0.0
#
# Episode 343/500
# Episode finished with total reward: 0.0
#
# Episode 344/500
# Episode finished with total reward: 0.0
#
# Episode 345/500
# Episode finished with total reward: 0.0
#
# Episode 346/500
# Episode finished with total reward: 1.0
#
# Episode 347/500
# Episode finished with total reward: 0.0
#
# Episode 348/500
# Episode finished with total reward: 1.0
#
# Episode 349/500
# Episode finished with total reward: 1.0
#
# Episode 350/500
# Episode finished with total reward: 1.0
#
# Episode 351/500
# Episode finished with total reward: 0.0
#
# Episode 352/500
# Episode finished with total reward: 1.0
#
# Episode 353/500
# Episode finished with total reward: 1.0
#
# Episode 354/500
# Episode finished with total reward: 0.0
#
# Episode 355/500
# Episode finished with total reward: 0.0
#
# Episode 356/500
# Episode finished with total reward: 1.0
#
# Episode 357/500
# Episode finished with total reward: 0.0
#
# Episode 358/500
# Episode finished with total reward: 1.0
#
# Episode 359/500
# Episode finished with total reward: 1.0
#
# Episode 360/500
# Episode finished with total reward: 0.0
#
# Episode 361/500
# Episode finished with total reward: 1.0
#
# Episode 362/500
# Episode finished with total reward: 1.0
#
# Episode 363/500
# Episode finished with total reward: 1.0
#
# Episode 364/500
# Episode finished with total reward: 0.0
#
# Episode 365/500
# Episode finished with total reward: 0.0
#
# Episode 366/500
# Episode finished with total reward: 0.0
#
# Episode 367/500
# Episode finished with total reward: 1.0
#
# Episode 368/500
# Episode finished with total reward: 1.0
#
# Episode 369/500
# Episode finished with total reward: 1.0
#
# Episode 370/500
# Episode finished with total reward: 1.0
#
# Episode 371/500
# Episode finished with total reward: 1.0
#
# Episode 372/500
# Episode finished with total reward: 1.0
#
# Episode 373/500
# Episode finished with total reward: 1.0
#
# Episode 374/500
# Episode finished with total reward: 0.0
#
# Episode 375/500
# Episode finished with total reward: 1.0
#
# Episode 376/500
# Episode finished with total reward: 1.0
#
# Episode 377/500
# Episode finished with total reward: 0.0
#
# Episode 378/500
# Episode finished with total reward: 1.0
#
# Episode 379/500
# Episode finished with total reward: 1.0
#
# Episode 380/500
# Episode finished with total reward: 1.0
#
# Episode 381/500
# Episode finished with total reward: 1.0
#
# Episode 382/500
# Episode finished with total reward: 1.0
#
# Episode 383/500
# Episode finished with total reward: 1.0
#
# Episode 384/500
# Episode finished with total reward: 1.0
#
# Episode 385/500
# Episode finished with total reward: 1.0
#
# Episode 386/500
# Episode finished with total reward: 1.0
#
# Episode 387/500
# Episode finished with total reward: 1.0
#
# Episode 388/500
# Episode finished with total reward: 1.0
#
# Episode 389/500
# Episode finished with total reward: 1.0
#
# Episode 390/500
# Episode finished with total reward: 1.0
#
# Episode 391/500
# Episode finished with total reward: 1.0
#
# Episode 392/500
# Episode finished with total reward: 1.0
#
# Episode 393/500
# Episode finished with total reward: 1.0
#
# Episode 394/500
# Episode finished with total reward: 1.0
#
# Episode 395/500
# Episode finished with total reward: 1.0
#
# Episode 396/500
# Episode finished with total reward: 0.0
#
# Episode 397/500
# Episode finished with total reward: 1.0
#
# Episode 398/500
# Episode finished with total reward: 1.0
#
# Episode 399/500
# Episode finished with total reward: 1.0
#
# Episode 400/500
# Episode finished with total reward: 1.0
#
# Episode 401/500
# Episode finished with total reward: 1.0
#
# Episode 402/500
# Episode finished with total reward: 1.0
#
# Episode 403/500
# Episode finished with total reward: 1.0
#
# Episode 404/500
# Episode finished with total reward: 1.0
#
# Episode 405/500
# Episode finished with total reward: 1.0
#
# Episode 406/500
# Episode finished with total reward: 1.0
#
# Episode 407/500
# Episode finished with total reward: 0.0
#
# Episode 408/500
# Episode finished with total reward: 1.0
#
# Episode 409/500
# Episode finished with total reward: 1.0
#
# Episode 410/500
# Episode finished with total reward: 1.0
#
# Episode 411/500
# Episode finished with total reward: 1.0
#
# Episode 412/500
# Episode finished with total reward: 1.0
#
# Episode 413/500
# Episode finished with total reward: 1.0
#
# Episode 414/500
# Episode finished with total reward: 0.0
#
# Episode 415/500
# Episode finished with total reward: 1.0
#
# Episode 416/500
# Episode finished with total reward: 1.0
#
# Episode 417/500
# Episode finished with total reward: 1.0
#
# Episode 418/500
# Episode finished with total reward: 1.0
#
# Episode 419/500
# Episode finished with total reward: 0.0
#
# Episode 420/500
# Episode finished with total reward: 1.0
#
# Episode 421/500
# Episode finished with total reward: 1.0
#
# Episode 422/500
# Episode finished with total reward: 1.0
#
# Episode 423/500
# Episode finished with total reward: 1.0
#
# Episode 424/500
# Episode finished with total reward: 1.0
#
# Episode 425/500
# Episode finished with total reward: 1.0
#
# Episode 426/500
# Episode finished with total reward: 0.0
#
# Episode 427/500
# Episode finished with total reward: 1.0
#
# Episode 428/500
# Episode finished with total reward: 1.0
#
# Episode 429/500
# Episode finished with total reward: 1.0
#
# Episode 430/500
# Episode finished with total reward: 1.0
#
# Episode 431/500
# Episode finished with total reward: 1.0
#
# Episode 432/500
# Episode finished with total reward: 1.0
#
# Episode 433/500
# Episode finished with total reward: 1.0
#
# Episode 434/500
# Episode finished with total reward: 1.0
#
# Episode 435/500
# Episode finished with total reward: 1.0
#
# Episode 436/500
# Episode finished with total reward: 1.0
#
# Episode 437/500
# Episode finished with total reward: 1.0
#
# Episode 438/500
# Episode finished with total reward: 1.0
#
# Episode 439/500
# Episode finished with total reward: 1.0
#
# Episode 440/500
# Episode finished with total reward: 1.0
#
# Episode 441/500
# Episode finished with total reward: 1.0
#
# Episode 442/500
# Episode finished with total reward: 1.0
#
# Episode 443/500
# Episode finished with total reward: 0.0
#
# Episode 444/500
# Episode finished with total reward: 1.0
#
# Episode 445/500
# Episode finished with total reward: 0.0
#
# Episode 446/500
# Episode finished with total reward: 1.0
#
# Episode 447/500
# Episode finished with total reward: 1.0
#
# Episode 448/500
# Episode finished with total reward: 1.0
#
# Episode 449/500
# Episode finished with total reward: 0.0
#
# Episode 450/500
# Episode finished with total reward: 1.0
#
# Episode 451/500
# Episode finished with total reward: 1.0
#
# Episode 452/500
# Episode finished with total reward: 0.0
#
# Episode 453/500
# Episode finished with total reward: 1.0
#
# Episode 454/500
# Episode finished with total reward: 1.0
#
# Episode 455/500
# Episode finished with total reward: 1.0
#
# Episode 456/500
# Episode finished with total reward: 1.0
#
# Episode 457/500
# Episode finished with total reward: 1.0
#
# Episode 458/500
# Episode finished with total reward: 1.0
#
# Episode 459/500
# Episode finished with total reward: 1.0
#
# Episode 460/500
# Episode finished with total reward: 1.0
#
# Episode 461/500
# Episode finished with total reward: 1.0
#
# Episode 462/500
# Episode finished with total reward: 1.0
#
# Episode 463/500
# Episode finished with total reward: 1.0
#
# Episode 464/500
# Episode finished with total reward: 1.0
#
# Episode 465/500
# Episode finished with total reward: 1.0
#
# Episode 466/500
# Episode finished with total reward: 0.0
#
# Episode 467/500
# Episode finished with total reward: 1.0
#
# Episode 468/500
# Episode finished with total reward: 1.0
#
# Episode 469/500
# Episode finished with total reward: 1.0
#
# Episode 470/500
# Episode finished with total reward: 0.0
#
# Episode 471/500
# Episode finished with total reward: 1.0
#
# Episode 472/500
# Episode finished with total reward: 1.0
#
# Episode 473/500
# Episode finished with total reward: 1.0
#
# Episode 474/500
# Episode finished with total reward: 1.0
#
# Episode 475/500
# Episode finished with total reward: 1.0
#
# Episode 476/500
# Episode finished with total reward: 1.0
#
# Episode 477/500
# Episode finished with total reward: 1.0
#
# Episode 478/500
# Episode finished with total reward: 1.0
#
# Episode 479/500
# Episode finished with total reward: 0.0
#
# Episode 480/500
# Episode finished with total reward: 1.0
#
# Episode 481/500
# Episode finished with total reward: 0.0
#
# Episode 482/500
# Episode finished with total reward: 1.0
#
# Episode 483/500
# Episode finished with total reward: 1.0
#
# Episode 484/500
# Episode finished with total reward: 1.0
#
# Episode 485/500
# Episode finished with total reward: 1.0
#
# Episode 486/500
# Episode finished with total reward: 1.0
#
# Episode 487/500
# Episode finished with total reward: 1.0
#
# Episode 488/500
# Episode finished with total reward: 1.0
#
# Episode 489/500
# Episode finished with total reward: 1.0
#
# Episode 490/500
# Episode finished with total reward: 1.0
#
# Episode 491/500
# Episode finished with total reward: 1.0
#
# Episode 492/500
# Episode finished with total reward: 1.0
#
# Episode 493/500
# Episode finished with total reward: 1.0
#
# Episode 494/500
# Episode finished with total reward: 1.0
#
# Episode 495/500
# Episode finished with total reward: 1.0
#
# Episode 496/500
# Episode finished with total reward: 1.0
#
# Episode 497/500
# Episode finished with total reward: 1.0
#
# Episode 498/500
# Episode finished with total reward: 1.0
#
# Episode 499/500
# Episode finished with total reward: 1.0
#
# Episode 500/500
# Episode finished with total reward: 1.0
#
# Total time for SARSA: 0.49 seconds
# Trained Q-Table:
# [[ 6.19329773e-01  3.52446944e-01  8.05426872e-01  6.41150674e-01]
#  [ 5.27511894e-01  2.63499223e-03  9.46951605e-01  5.66783395e-01]
#  [ 5.60680545e-01  9.63400424e-01  1.89569564e-01  5.30936400e-01]
#  [ 4.54165715e-01 -1.76536731e-04  4.29300652e-02 -1.26588262e-03]
#  [ 3.09966700e-01  3.04868736e-01  2.76389935e-03  6.03325199e-01]
#  [ 4.07806361e-04  3.19195817e-03  2.04889056e-03 -6.91903064e-03]
#  [ 2.65695259e-03  9.57516167e-01  4.19887332e-03  5.05108222e-01]
#  [-6.87488633e-03  4.65439992e-03 -1.40696465e-03 -2.75405383e-03]
#  [ 5.47455102e-01  4.48917291e-03  5.58336279e-01  4.66266387e-01]
#  [ 5.84108332e-01  9.39376551e-01  5.53672586e-01  2.67375293e-03]
#  [ 8.04906459e-01  9.63935427e-01  7.41934905e-03  7.54803888e-01]
#  [ 7.52841423e-03  5.40450469e-03  1.67092623e-03 -9.02758486e-03]
#  [ 2.71864046e-03 -9.22167405e-03  4.99127381e-03 -1.93422643e-03]
#  [ 2.73999541e-04  6.87294392e-01  9.94253139e-01  3.24828137e-01]
#  [ 8.48915208e-01  9.09073474e-01  1.00086027e+00  5.99679468e-01]
#  [-6.55251783e-03 -9.43612934e-03  5.28543087e-03 -8.70182610e-03]]
#
# Comparison Table:
# Algorithm    | Time (seconds)
# ------------------------------
# SARSA        | 0.49

# %%
# For visualizing frozen lake but not able to visualize
import os
os.environ["XDG_RUNTIME_DIR"] = "/tmp/runtime-$(id -u)"

# i also tried with this one but didn't work
env = gym.make("FrozenLake-v1", is_slippery=False, render_mode="human")
